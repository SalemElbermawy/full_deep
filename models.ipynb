# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import keras
# Out:
# c:\Users\Access\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\Access\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# ...

# %%
data=pd.read_csv("Titanic-Dataset.csv")

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print(data.shape)
data.info()
# Out:
# (891, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# age/cabin/embarked
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# delete imimportant columns

data.drop(["PassengerId","Name"],inplace=True,axis=1)
data.drop("Ticket",axis=1,inplace=True)

# %%
data.sample(20)
# Out:
#      Survived  Pclass     Sex    Age  SibSp  Parch      Fare    Cabin Embarked
# 623         0       3    male  21.00      0      0    7.8542      NaN        S
# 771         0       3    male  48.00      0      0    7.8542      NaN        S
# 653         1       3  female    NaN      0      0    7.8292      NaN        Q
# 831         1       2    male   0.83      1      1   18.7500      NaN        S
# 26          0       3    male    NaN      0      0    7.2250      NaN        C
# 171         0       3    male   4.00      4      1   29.1250      NaN        Q
# 786         1       3  female  18.00      0      0    7.4958      NaN        S
# 433         0       3    male  17.00      0      0    7.1250      NaN        S
# 554         1       3  female  22.00      0      0    7.7750      NaN        S
# 583         0       1    male  36.00      0      0   40.1250      A10        C
# 390         1       1    male  36.00      1      2  120.0000  B96 B98        S
# ...

# %%
len(data["Cabin"].unique())
# Out:
# 148

# %%
data.drop("Cabin",axis=1,inplace=True)

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
data["Age"]=data["Age"].fillna(data["Age"].mean())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
data["Embarked"]=data["Embarked"].fillna(data["Embarked"].mode()[0])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
print(data["Embarked"].unique())
print(data["Sex"].unique())
# Out:
# ['S' 'C' 'Q']
# ['male' 'female']

# %%
encoding_embarked={
    "S":1,
    "C":2,
    "Q":3
}

data["Embarked"] = data["Embarked"].map(
    encoding_embarked
)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 55.8+ KB

# %%
sex_encoding={
    "male":1,
    "female":0
}

data["Sex"]=data["Sex"].map(sex_encoding)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 55.8 KB

# %%
y=data["Survived"]
x=data.drop("Survived",axis=1)

# %%
from sklearn.model_selection import train_test_split

train_x,test_x,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=33)

# %%
print(train_x.shape)
print(y_train.shape)
print(y_test.shape)
print(test_x.shape)
# Out:
# (712, 7)
# (712,)
# (179,)
# (179, 7)

# %%
import keras

# %%
model=keras.Sequential([
    keras.layers.Dense(32,activation="relu"),
    # keras.layers.Dropout(0.4),
    keras.layers.Dense(64,activation="relu"),
    # keras.layers.Dropout(0.4),
    # keras.layers.Dense(16,activation="relu"),
    keras.layers.Dense(1,activation="sigmoid")
])

# %%
model.compile(
    metrics=["accuracy"], optimizer="adam",loss="binary_crossentropy"
)

# %%
history=model.fit(
    train_x,y_train,epochs=60,batch_size=4,verbose=1
)
# Out:
# Epoch 1/60
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.6685 - loss: 0.7624
# Epoch 2/60
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7093 - loss: 0.6222
# Epoch 3/60
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7022 - loss: 0.6306
# Epoch 4/60
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7289 - loss: 0.5630
# Epoch 5/60
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7261 - loss: 0.5535
# Epoch 6/60
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7472 - loss: 0.5331
# Epoch 7/60
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7500 - loss: 0.5277
# Epoch 8/60
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7767 - loss: 0.5097
# Epoch 9/60
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7289 - loss: 0.5816
# Epoch 10/60
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7781 - loss: 0.4758
# Epoch 11/60
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7430 - loss: 0.5797
# ...

# %%
model.evaluate(test_x,y_test)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8045 - loss: 0.5199
# [0.5199368596076965, 0.8044692873954773]

# %%
model.save("titanic_model.keras")

# %%
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')

plt.title("Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")

plt.legend()
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[191], line 2
#       1 plt.plot(history.history['accuracy'], label='Train Accuracy')
# ----> 2 plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
#       4 plt.title("Accuracy")
#       5 plt.xlabel("Epochs")
#
# KeyError: 'val_accuracy'

# %%
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title("Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")

plt.legend()
plt.grid(True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[192], line 2
#       1 plt.plot(history.history['loss'], label='Train Loss')
# ----> 2 plt.plot(history.history['val_loss'], label='Validation Loss')
#       4 plt.title("Loss")
#       5 plt.xlabel("Epochs")
#
# KeyError: 'val_loss'

# %%
import matplotlib.pyplot as plt

for key in history.history.keys():
    
    plt.figure(figsize=(6,4))
    
    plt.plot(history.history[key], label=key)
    
    plt.title(f"{key} over epochs")
    plt.xlabel("Epochs")
    plt.ylabel(key)
    
    plt.legend()
    plt.grid(True)
    
    plt.show()

# %%
data=pd.read_csv("housing.csv")

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data["total_bedrooms"]=data["total_bedrooms"].fillna(data["total_bedrooms"].mean())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.drop(["longitude","latitude"],inplace=True,axis=1)

# %%
data["ocean_proximity"].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

encoder=LabelEncoder()

data["ocean_proximity"]=encoder.fit_transform(data["ocean_proximity"])

# %%
data.sample(5)
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 19924                20.0       2025.0           328.0      1039.0
# 1285                 50.0       1120.0           281.0       625.0
# 14389                16.0       1953.0           404.0       798.0
# 15545                23.0       3400.0           501.0      1383.0
# 8105                 39.0       1598.0           458.0      1691.0
#
#        households  median_income  median_house_value  ocean_proximity
# 19924       346.0         3.5313             82800.0                1
# 1285        239.0         1.5988             96400.0                1
# 14389       385.0         4.8167            169800.0                4
# 15545       488.0         4.9844            249100.0                0
# 8105        399.0         2.3605            141800.0                4

# %%
data.describe()
# Out:
#        housing_median_age   total_rooms  total_bedrooms    population  \
# count        20640.000000  20640.000000    20640.000000  20640.000000
# mean            28.639486   2635.763081      537.870553   1425.476744
# std             12.585558   2181.615252      419.266592   1132.462122
# min              1.000000      2.000000        1.000000      3.000000
# 25%             18.000000   1447.750000      297.000000    787.000000
# 50%             29.000000   2127.000000      438.000000   1166.000000
# 75%             37.000000   3148.000000      643.250000   1725.000000
# max             52.000000  39320.000000     6445.000000  35682.000000
#
#          households  median_income  median_house_value  ocean_proximity
# count  20640.000000   20640.000000        20640.000000     20640.000000
# mean     499.539680       3.870671       206855.816909         1.165843
# std      382.329753       1.899822       115395.615874         1.420662
# ...

# %%
encoder.transform([['<1H OCEAN'], ['INLAND'], ['ISLAND'], ['NEAR BAY'], ['NEAR OCEAN']])
# Out:
# c:\Users\Access\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# array([0, 1, 2, 3, 4])

# %%
x=data.drop("median_house_value",axis=1)
y=data["median_house_value"]

# %%
x.sample(5)
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 18714                10.0       7949.0          1309.0      3176.0
# 14082                52.0       1484.0           224.0       498.0
# 702                   6.0       2445.0           590.0      1189.0
# 9565                 11.0       3946.0           978.0      2814.0
# 2570                 27.0       3046.0           605.0      1407.0
#
#        households  median_income  ocean_proximity
# 18714      1163.0         4.1099                1
# 14082       223.0         6.6053                4
# 702         573.0         3.8958                3
# 9565        953.0         2.0179                1
# 2570        571.0         2.9143                4

# %%
from sklearn.model_selection import train_test_split

train_x,test_x,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=33)

# %%
import keras

# %%
model = keras.Sequential([
    keras.layers.Dense(16,activation="relu"),
    keras.layers.Dense(32,activation="relu"),
    keras.layers.Dense(64,activation="relu"),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(1)
])

# %%
model.compile(
    loss="mse",
    metrics=["mse","mae",keras.metrics.R2Score()],
    optimizer="adam"
)

# %%
history=model.fit(
    train_x,y_train,epochs=50,batch_size=32,verbose=1
)
# Out:
# Epoch 1/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - loss: 33213452288.0000 - mae: 138602.8438 - mse: 33213452288.0000 - r2_score: -1.5076
# Epoch 2/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 27810484224.0000 - mae: 121349.5000 - mse: 27810484224.0000 - r2_score: -1.0997
# Epoch 3/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 27247693824.0000 - mae: 119663.9297 - mse: 27247693824.0000 - r2_score: -1.0572
# Epoch 4/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 26433472512.0000 - mae: 117706.7891 - mse: 26433472512.0000 - r2_score: -0.9957
# Epoch 5/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - loss: 25178271744.0000 - mae: 114690.1250 - mse: 25178271744.0000 - r2_score: -0.9010
# Epoch 6/50
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - loss: 23124666368.0000 - mae: 109233.9297 - mse: 23124666368.0000 - r2_score: -0.7459
# Epoch 7/50
# ...

# %%
model.evaluate(test_x,y_test)
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 4816007168.0000 - mae: 53028.2852 - mse: 4816007168.0000 - r2_score: 0.6458
# [4816007168.0, 4816007168.0, 53028.28515625, 0.6457960605621338]

# %%
data.describe()

# %%
import matplotlib.pyplot as plt

for key in history.history.keys():
    
    plt.figure(figsize=(6,4))
    
    plt.plot(history.history[key], label=key)
    
    plt.title(f"{key} over epochs")
    plt.xlabel("Epochs")
    plt.ylabel(key)
    
    plt.legend()
    plt.grid(True)
    
    plt.show()

# %%
model.save("ca_housing.keras")

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  ocean_proximity
# 0       322.0       126.0         8.3252            452600.0                3
# 1      2401.0      1138.0         8.3014            358500.0                3
# 2       496.0       177.0         7.2574            352100.0                3
# 3       558.0       219.0         5.6431            341300.0                3
# 4       565.0       259.0         3.8462            342200.0                3

# %%
train_x.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3578     -118.53     34.24                24.0       2718.0           719.0
# 11132    -117.93     33.85                25.0       1026.0           288.0
# 14862    -117.09     32.65                25.0       3509.0           985.0
# 4929     -118.24     33.99                41.0       1425.0           372.0
# 7805     -118.09     33.89                42.0       1150.0           215.0
#
#        population  households  median_income  ocean_proximity
# 3578       3018.0       644.0         2.9076                0
# 11132      1646.0       283.0         4.2019                0
# 14862      2359.0       899.0         2.6296                4
# 4929       1803.0       353.0         1.6731                0
# 7805        708.0       204.0         3.6875                0

# %%
data=pd.read_csv("Iris.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
map_encoding={
    
    'Iris-setosa':0, 'Iris-versicolor':1, 'Iris-virginica':2
    
}


data["Species"]=data["Species"].map(map_encoding)

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
data.sample(20)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 93    94            5.0           2.3            3.3           1.0        1
# 42    43            4.4           3.2            1.3           0.2        0
# 52    53            6.9           3.1            4.9           1.5        1
# 46    47            5.1           3.8            1.6           0.2        0
# 16    17            5.4           3.9            1.3           0.4        0
# 34    35            4.9           3.1            1.5           0.1        0
# 119  120            6.0           2.2            5.0           1.5        2
# 55    56            5.7           2.8            4.5           1.3        1
# 7      8            5.0           3.4            1.5           0.2        0
# 79    80            5.7           2.6            3.5           1.0        1
# 49    50            5.0           3.3            1.4           0.2        0
# ...

# %%
data.drop("Id",inplace=True,axis=1)
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
x=data.drop("Species",axis=1)
y=data["Species"]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=34)

# %%
model=keras.Sequential([
    keras.layers.Dense(16,activation="relu"),
    keras.layers.Dense(32,activation="relu"),
    keras.layers.Dense(3,activation="softmax")
])

model.compile(
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
    optimizer="adam"
)

# %%
history=model.fit(
    x_train,
    y_train,
    epochs=60,
)
# Out:
# Epoch 1/60
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.3250 - loss: 1.2823
# Epoch 2/60
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3250 - loss: 1.2136
# Epoch 3/60
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3250 - loss: 1.1563
# Epoch 4/60
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3250 - loss: 1.1131
# Epoch 5/60
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3250 - loss: 1.0802
# Epoch 6/60
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3250 - loss: 1.0558
# Epoch 7/60
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.5750 - loss: 1.0378
# Epoch 8/60
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7083 - loss: 1.0269
# Epoch 9/60
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7083 - loss: 1.0143
# Epoch 10/60
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7083 - loss: 1.0011
# Epoch 11/60
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7083 - loss: 0.9910
# Epoch 12/60
# ...

# %%
model.evaluate(x_test,y_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step - accuracy: 0.9000 - loss: 0.4435
# [0.443502277135849, 0.8999999761581421]

# %%
import matplotlib.pyplot as plt

for key in history.history.keys():
    
    plt.figure(figsize=(6,4))
    
    plt.plot(history.history[key], label=key)
    
    plt.title(f"{key} over epochs")
    plt.xlabel("Epochs")
    plt.ylabel(key)
    
    plt.legend()
    plt.grid(True)
    
    plt.show()

# %%
y_pre=model.predict(x_test)
y_pre[0:5]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# array([[0.11362394, 0.53125936, 0.35511667],
#        [0.01469635, 0.2601353 , 0.72516835],
#        [0.8916815 , 0.09731906, 0.01099941],
#        [0.16294602, 0.5044011 , 0.3326529 ],
#        [0.0231724 , 0.3129686 , 0.66385907]], dtype=float32)

# %%
model.save("iris.keras")

# %%
data= pd.read_csv("breast-cancer.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave_points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
print(data.isna().sum())
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave_points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave_points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
data.select_dtypes(include="object").columns
# Out:
# Index(['diagnosis'], dtype='object')

# %%
corr_conf=data.drop("diagnosis",axis=1).corr()
plt.figure(figsize=(9,5))
sns.heatmap(corr_conf)
# Out:
# <Axes: >

# %%
columns=data.columns

for c in columns:
    if "area" in c:
        data.drop(c,inplace=True,axis=1)

# %%
corr_conf=data.drop("diagnosis",axis=1).corr()
plt.figure(figsize=(9,5))
sns.heatmap(corr_conf)
# Out:
# <Axes: >

# %%
data.shape
# Out:
# (569, 29)

# %%
data.drop("id",axis=1,inplace=True)

# %%
columns=data.columns
for c in columns:
    if "se" in c or "worst" in c:
        data.drop(c,inplace=True,axis=1)

# %%
data.shape
# Out:
# (569, 10)

# %%
data.sample(5)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  smoothness_mean  \
# 43          M        13.28         20.28           87.32          0.10410
# 495         B        14.87         20.21           96.12          0.09587
# 49          B        13.49         22.30           86.91          0.08752
# 519         B        12.75         16.70           82.51          0.11250
# 340         B        14.42         16.54           94.15          0.09751
#
#      compactness_mean  concavity_mean  concave_points_mean  symmetry_mean  \
# 43            0.14360         0.09847              0.06158         0.1974
# 495           0.08345         0.06824              0.04951         0.1487
# 49            0.07698         0.04751              0.03384         0.1809
# 519           0.11170         0.03880              0.02995         0.2120
# 340           0.11390         0.08007              0.04223         0.1912
#
#      fractal_dimension_mean
# 43                  0.06782
# ...

# %%
data["diagnosis"].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
predict_encoding={
    "B":0,
    "M":1
}

data["diagnosis"]=data["diagnosis"].map(predict_encoding)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   diagnosis               569 non-null    int64
#  1   radius_mean             569 non-null    float64
#  2   texture_mean            569 non-null    float64
#  3   perimeter_mean          569 non-null    float64
#  4   smoothness_mean         569 non-null    float64
#  5   compactness_mean        569 non-null    float64
#  6   concavity_mean          569 non-null    float64
#  7   concave_points_mean     569 non-null    float64
#  8   symmetry_mean           569 non-null    float64
#  9   fractal_dimension_mean  569 non-null    float64
# dtypes: float64(9), int64(1)
# memory usage: 44.6 KB

# %%
y=data["diagnosis"]
x=data.drop("diagnosis",axis=1)

# %%
x.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean  smoothness_mean  \
# count   569.000000    569.000000      569.000000       569.000000
# mean     14.127292     19.289649       91.969033         0.096360
# std       3.524049      4.301036       24.298981         0.014064
# min       6.981000      9.710000       43.790000         0.052630
# 25%      11.700000     16.170000       75.170000         0.086370
# 50%      13.370000     18.840000       86.240000         0.095870
# 75%      15.780000     21.800000      104.100000         0.105300
# max      28.110000     39.280000      188.500000         0.163400
#
#        compactness_mean  concavity_mean  concave_points_mean  symmetry_mean  \
# count        569.000000      569.000000           569.000000     569.000000
# mean           0.104341        0.088799             0.048919       0.181162
# std            0.052813        0.079720             0.038803       0.027414
# ...

# %%
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  smoothness_mean  \
# 0        17.99         10.38          122.80          0.11840
# 1        20.57         17.77          132.90          0.08474
# 2        19.69         21.25          130.00          0.10960
# 3        11.42         20.38           77.58          0.14250
# 4        20.29         14.34          135.10          0.10030
#
#    compactness_mean  concavity_mean  concave_points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean
# 0                 0.07871
# 1                 0.05667
# 2                 0.05999
# 3                 0.09744
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=22)

# %%
model=keras.Sequential([
    keras.layers.Dense(32,activation="relu"),
    keras.layers.Dense(64,activation="relu"),
    keras.layers.Dense(1,activation="sigmoid")
])

model.compile(
    metrics=["accuracy"], optimizer="adam",loss="binary_crossentropy"
)

# %%
history=model.fit(x_train,y_train,epochs=96)
# Out:
# Epoch 1/96
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.6000 - loss: 0.7096
# Epoch 2/96
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6176 - loss: 0.6471
# Epoch 3/96
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6681 - loss: 0.6211
# Epoch 4/96
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6637 - loss: 0.6135
# Epoch 5/96
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6659 - loss: 0.6110
# Epoch 6/96
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6264 - loss: 0.6152
# Epoch 7/96
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5934 - loss: 0.6803
# Epoch 8/96
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6308 - loss: 0.6913
# Epoch 9/96
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6703 - loss: 0.5992
# Epoch 10/96
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6615 - loss: 0.6154
# Epoch 11/96
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7231 - loss: 0.5876
# Epoch 12/96
# ...

# %%
model.evaluate(x_test,y_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9386 - loss: 0.2386
# [0.23858340084552765, 0.9385964870452881]

# %%
import matplotlib.pyplot as plt

for key in history.history.keys():
    
    plt.figure(figsize=(6,4))
    
    plt.plot(history.history[key], label=key)
    
    plt.title(f"{key} over epochs")
    plt.xlabel("Epochs")
    plt.ylabel(key)
    
    plt.legend()
    plt.grid(True)
    
    plt.show()

# %%
model.save("brease.keras")
